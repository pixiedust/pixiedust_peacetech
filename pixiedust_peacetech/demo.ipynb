# %%
from pixiedust_peacetech.dashBoard import *
import json

nlu = json.load(open('nlu.cred'))
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version=nlu['version'],
    username=nlu['username'],
    password=nlu['password'])

headers=json.load(open('datahub.cred'))
PixieAppBoard().run(runInDialog='true')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
# ...

# %%
ins = PixieAppBoard_instance

# %%
display(ins.temperature)
# Out:
# <div class="pixiedust" pixiedust="{&quot;prefix&quot;: &quot;7ce837b0&quot;, &quot;command&quot;: &quot;display(ins.temperature,cell_id=&apos;2BB58B99DDEA481A89C2648453686B85&apos;,nostore_pixiedust=&apos;true&apos;,rowCount=&apos;500&apos;,handlerId=&apos;lineChart&apos;,valueFields=&apos;value&apos;,rendererId=&apos;matplotlib&apos;,timeseries=&apos;false&apos;,keyFields=&apos;time&apos;,aggregation=&apos;SUM&apos;,nostore_cw=&apos;1098&apos;,org_params=&apos;nostore_pixiedust&apos;,nostore_bokeh=&apos;true&apos;)&quot;, &quot;options&quot;: {&quot;nostore_bokeh&quot;: &quot;true&quot;, &quot;cell_id&quot;: &quot;2BB58B99DDEA481A89C2648453686B85&quot;, &quot;org_params&quot;: &quot;nostore_pixiedust&quot;, &quot;aggregation&quot;: &quot;SUM&quot;, &quot;nostore_cw&quot;: &quot;1098&quot;, &quot;rowCount&quot;: &quot;500&quot;, &quot;handlerId&quot;: &quot;lineChart&quot;, &quot;valueFields&quot;: &quot;value&quot;, &quot;rendererId&quot;: &quot;matplotlib&quot;, &quot;timeseries&qu
# ...

# %%
display(ins.precipitation)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><img style="max-width:initial !important" src="data:image/png;base64,..." class="pd_save is-viewer-good">
